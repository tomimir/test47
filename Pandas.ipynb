# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel("AAPL.xlsx")
data
# Out:
#       timestamp    open    high     low   close  adjusted_close    volume
# 0    2020-03-06  282.00  290.82  281.23  289.03        289.0300  56544246
# 1    2020-03-05  295.52  299.55  291.41  292.92        292.9200  46893219
# 2    2020-03-04  296.44  303.40  293.13  302.74        302.7400  54794568
# 3    2020-03-03  303.67  304.00  285.80  289.32        289.3200  79868852
# 4    2020-03-02  282.28  301.44  277.72  298.81        298.8100  85349339
# ...         ...     ...     ...     ...     ...             ...       ...
# 5028 2000-03-10  121.69  127.94  121.00  125.75          3.8979   2219700
# 5029 2000-03-09  120.87  125.00  118.25  122.25          3.7894   2470700
# 5030 2000-03-08  122.87  123.94  118.56  122.00          3.7816   2421700
# 5031 2000-03-07  126.44  127.44  121.12  122.87          3.8086   2437600
# 5032 2000-03-06  126.00  129.13  125.00  125.69          3.8960   1880000
#
# [5033 rows x 7 columns]

# %%
mascara=data.timestamp >= "2008-05-15"
data[mascara].tail(n=3)
# Out:
#       timestamp    open    high    low     close  adjusted_close    volume
# 2970 2008-05-19  187.90  188.69  181.3  183.6000         22.7642  33779300
# 2971 2008-05-16  190.30  190.30  187.0  187.6201         23.2626  27348900
# 2972 2008-05-15  186.78  189.90  184.2  189.7300         23.5242  31186000

# %%
data1=data.set_index("timestamp")
data1.loc["2008-05-20":"2008-05-15"]
data1.tail(3)
# Out:
#               open    high     low   close  adjusted_close   volume
# timestamp
# 2000-03-08  122.87  123.94  118.56  122.00          3.7816  2421700
# 2000-03-07  126.44  127.44  121.12  122.87          3.8086  2437600
# 2000-03-06  126.00  129.13  125.00  125.69          3.8960  1880000

# %%
mascara1=np.logical_and(data.timestamp >="2008-05-15",data.timestamp <="2011-08-20")
print(data[mascara1])
# Out:
#       timestamp    open    high     low     close  adjusted_close    volume
# 2149 2011-08-19  362.17  367.00  356.00  356.0300         44.1435  27710300
# 2150 2011-08-18  370.84  372.65  361.37  366.0500         45.3858  30408400
# 2151 2011-08-17  382.31  384.52  378.00  380.4400         47.1700  15787900
# 2152 2011-08-16  381.52  383.37  376.06  380.4800         47.1750  17812500
# 2153 2011-08-15  379.63  384.97  378.09  383.4100         47.5382  16448000
# ...         ...     ...     ...     ...       ...             ...       ...
# 2968 2008-05-21  185.61  188.00  176.25  178.1900         22.0934  41344900
# 2969 2008-05-20  181.83  186.16  180.12  185.9000         23.0494  34637500
# 2970 2008-05-19  187.90  188.69  181.30  183.6000         22.7642  33779300
# 2971 2008-05-16  190.30  190.30  187.00  187.6201         23.2626  27348900
# 2972 2008-05-15  186.78  189.90  184.20  189.7300         23.5242  31186000
#
# [824 rows x 7 columns]

# %%
mascara2=np.logical_and(np.logical_and(data.timestamp >="2008-05-15",data.timestamp <="2011-08-20"),data.close>data.open)
print(data[mascara2])
# Out:
#       timestamp    open    high     low   close  adjusted_close    volume
# 2153 2011-08-15  379.63  384.97  378.09  383.41         47.5382  16448000
# 2155 2011-08-11  370.52  375.45  364.72  373.70         46.3343  26498900
# 2157 2011-08-09  361.30  374.61  355.00  374.01         46.3728  38663700
# 2161 2011-08-03  390.98  393.55  382.24  392.57         48.6740  26161000
# 2164 2011-07-29  387.64  395.15  384.00  390.48         48.4148  22592300
# ...         ...     ...     ...     ...     ...             ...       ...
# 2962 2008-05-30  187.50  189.54  187.38  188.75         23.4027  21792300
# 2965 2008-05-27  182.80  186.43  181.84  186.43         23.1151  28210900
# 2966 2008-05-23  180.75  181.99  177.80  181.17         22.4629  32389900
# 2969 2008-05-20  181.83  186.16  180.12  185.90         23.0494  34637500
# 2972 2008-05-15  186.78  189.90  184.20  189.73         23.5242  31186000
#
# [421 rows x 7 columns]

# %%
mascara2=np.logical_and(np.logical_and(data.timestamp >="2008-05-15",data.timestamp <="2011-08-20"),data.high/data.open>1.07)
data[mascara2].drop(['volume','adjusted_close'],axis=1)
# Out:
#       timestamp      open    high     low   close
# 2832 2008-12-03   89.4000   96.23   88.80   95.90
# 2838 2008-11-24   85.2100   94.79   84.84   92.95
# 2845 2008-11-13   89.8700   96.44   86.02   96.44
# 2856 2008-10-29  100.8600  109.54   99.94  104.55
# 2859 2008-10-24   90.3300   97.90   90.11   96.38
# 2869 2008-10-10   85.7000  100.00   85.00   96.80
# 2871 2008-10-08   85.9125   96.33   85.68   89.79
# 2873 2008-10-06   91.9600   98.78   87.54   98.14
# 2885 2008-09-18  130.5700  140.00  120.68  134.09
# 2926 2008-07-22  148.9000  162.76  146.53  162.02

# %%
data["up intradiario"]=data.high/data.open
mascara3=np.logical_and(data.timestamp>"2008-01-01",data.timestamp<"2008-12-31")
data[mascara3].sort_values("up intradiario",ascending=False).head()
# Out:
#       timestamp      open    high     low   close  adjusted_close    volume  \
# 2869 2008-10-10   85.7000  100.00   85.00   96.80         12.0020  79260700
# 2871 2008-10-08   85.9125   96.33   85.68   89.79         11.1329  78847900
# 2838 2008-11-24   85.2100   94.79   84.84   92.95         11.5247  51509200
# 2926 2008-07-22  148.9000  162.76  146.53  162.02         20.0885  67128300
# 2856 2008-10-29  100.8600  109.54   99.94  104.55         12.9629  69677800
#
#       intradiario  upsiede_intradiario  up intradiario
# 2869     1.166861             1.166861        1.166861
# 2871     1.121257             1.121257        1.121257
# 2838     1.112428             1.112428        1.112428
# 2926     1.093083             1.093083        1.093083
# 2856     1.086060             1.086060        1.086060

# %%
data["intradiario"]=data.low/data.open - 1
mascara3=np.logical_and(data.timestamp>"2018-01-01",data.timestamp<"2018-12-31")
data[mascara3].sort_values("intradiario",ascending=True).head().drop('upsiede_intradiario',axis=1)
# Out:
#      timestamp    open    high     low   close  adjusted_close    volume  \
# 339 2018-10-29  219.19  219.69  206.09  212.24        207.8590  45935520
# 302 2018-12-21  156.86  158.16  149.63  150.73        148.1355  95744384
# 520 2018-02-09  157.07  157.89  150.24  156.41        152.0559  66723743
# 352 2018-10-10  225.46  226.35  216.05  216.36        211.8939  41990554
# 304 2018-12-19  166.00  167.45  159.09  160.89        158.1206  49047297
#
#      intradiario  up intradiario
# 339    -0.059766        1.002281
# 302    -0.046092        1.008288
# 520    -0.043484        1.005221
# 352    -0.041737        1.003947
# 304    -0.041627        1.008735

# %%
data["volumen"]=data.volume/data["volume"].mean()
mascara4=data.volumen>5
data[mascara4].sort_values("volumen",ascending=True).head(10)
print(data["volume"].mean())
data[mascara4]
# Out:
# 23694203.887343533
#       timestamp     open      high      low    close  adjusted_close  \
# 1034 2016-01-27   96.040   96.6289   93.340   93.420         87.0791
# 1141 2015-08-24   94.870  108.8000   92.000  103.120         95.7091
# 1142 2015-08-21  110.430  111.9000  105.645  105.760         98.1594
# 1155 2015-08-04  117.420  117.7000  113.250  114.640        105.9228
# 1223 2015-04-28  134.455  134.5400  129.570  130.560        120.1335
# 1285 2015-01-28  117.625  118.1200  115.310  115.310        105.6872
# 1382 2014-09-09   99.080  103.0800   96.140   97.990         89.4259
# 1386 2014-09-03  103.100  103.2000   98.580   98.940         90.2929
# 3051 2008-01-23  136.190  140.0000  126.140  139.072         17.2433
# 3312 2007-01-09   86.450   92.9800   85.150   92.570         11.4776
# 4887 2000-09-29   28.190   29.0000   25.370   25.750          1.5963
#
#          volume  intradiario  upsiede_intradiario  up intradiario   volumen
# ...

# %%
import seaborn as sns

# %%
sns.displot(data[mascara4]['volumen'],bins=50)

# %%
sns.scatterplot(x="volumen",y="up intradiario",data=data[mascara4])
# Out:
# <AxesSubplot:xlabel='volumen', ylabel='up intradiario'>
