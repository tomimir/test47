# %%
import pandas as pd
df= pd.read_csv('DS_Bitácora_19_Data_con_VF.csv')

# %%
df.head()
# Out:
#   V1   V2           V3          V4           V5
# 0  C  1.0   986.175237  184.258917  2224.638050
# 1  C  1.0   994.130276         NaN  2570.213101
# 2  A  1.0   985.782622  196.893581  2309.238832
# 3  A  1.0  1029.464887  192.063247  2349.259233
# 4  A  1.0  1004.357092         NaN  2474.036357

# %%
df.isna().sum()
# Out:
# V1      0
# V2    159
# V3    104
# V4    413
# V5    118
# dtype: int64

# %%
data_copy=df.copy()

# %%
import seaborn as sns

# %%
sns.pairplot(data=df,hue='V1')

# %%
data_copy.fillna(data_copy.mean(),inplace=True)

# %%
sns.pairplot(data=data_copy,hue='V1')

# %%
from sklearn.impute import KNNImputer

# %%
import numpy as np

# %%
X=data_copy[['V4','V5']]

# %%
imputer=KNNImputer(n_neighbors=2)

# %%
imputer.fit_transform(X)
# Out:
# array([[ 184.25891731, 2224.63805045],
#        [ 196.41405616, 2570.2131006 ],
#        [ 196.8935806 , 2309.2388317 ],
#        ...,
#        [ 196.41405616, 2347.76063228],
#        [ 196.37351621, 2393.84748354],
#        [ 192.40620241, 2368.90678249]])

# %%
impute=pd.DataFrame(data= imputer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-1ceb1db93717> in <module>
# ----> 1 impute=pd.DataFrame(data= imputer)
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527         else:
#     528             if index is None or columns is None:
# --> 529                 raise ValueError("DataFrame constructor not properly called!")
#     530
#     531             if not dtype:
#
# ValueError: DataFrame constructor not properly called!
